# %%
# Exercise 1: Reverse a list in Python
# Exercise 2: Concatenate two lists index-wise
# Exercise 3: Turn every item of a list into its square
# Exercise 4: Concatenate two lists in the following order
# Exercise 5: Iterate both lists simultaneously
# Exercise 6: Remove empty strings from the list of strings
# Exercise 7: Add new item to list after a specified item
# Exercise 8: Extend nested list by adding the sublist
# Exercise 9: Replace list’s item with new value if found
# Exercise 10: Remove all occurrences of a specific item from a list.
# https://pynative.com/python-list-exercise-with-solutions/
# https://www.geeksforgeeks.org/python-list-exercise/
# https://www.w3resource.com/python-exercises/list/

# %%
#1
list1 = [100, 200, 300, 400, 500]
list1.reverse()
print(list1)
# Out:
# [500, 400, 300, 200, 100]

# %%
#2
list1 = ["M", "na", "i", "Ke"]
list2 = ["y", "me", "s", "lly"]
list3 = [i+j for i,j in zip(list1,list2)]
print(list3)
# for i in list1:
#     # print(i)
#     for j in list2:
#         print(i+j)
        # list3 = zip(list1,list2)
        # print(list3)
# list1.append(list2)
# print(list1)
# Out:
# ['My', 'name', 'is', 'Kelly']

# %%
#3
numbers = [1, 2, 3, 4, 5, 6, 7]
res = []
for i in numbers:
    # print(i**2,end=' ')
    res.append(i**2)
print(res)
# Out:
# [1, 4, 9, 16, 25, 36, 49]

# %%
#4
list1 = ["Hello ", "take "]
list2 = ["Dear", "Sir"]
list3 = []
temp = [i+j for i in list1 for j in list2]
print(temp)
# for i in list1:
#     for j in list2:
#         list3.append(i+j)
# print(list3)
# Out:
# ['Hello Dear', 'Hello Sir', 'take Dear', 'take Sir']

# %%
list1 = [10, 20, 30, 40, 50]
list2 = [100, 200, 300, 400, 500]
list2.reverse()
temp = [print(i,j) for i,j in zip(list1,list2)]
# print(temp)
# Out:
# 10 500
# 20 400
# 30 300
# 40 200
# 50 100

# %%
list1 = [10, 20, [300, 400, [5000, 6000], 500], 30, 40]
        #   0   1    2 0  2 1     
# list1[2][2].append(7000)
# print(list1[2][2])
# print(list1[][])
#0'a',1['bb',['ccc','ddd'],'ee','ff'],2'g',3'h'
#1[0'bb',1['ccc','ddd'],2'ee',3'ff']
#1[1[0'ccc',1'ddd']
list_te = ['a',['bb',['ccc','ddd'],'ee','ff'],'g','h']
print(list_te)
print('[0] is ',list_te[0])
print('[1] is ',list_te[1])
print('[1][0] is ',list_te[1][0])
print('[1][1][0] is ',list_te[1][1][0])
print('[1][1][1] is ',list_te[1][1][1])
print('[1][2] is ',list_te[1][2])
print('[1][3] is ',list_te[1][3])
print('[2] is ',list_te[2])
print('[3] is ',list_te[3])
list_te[1][1].insert(1,'xxx')
list_te[1][1].append('xxxx')
print(list_te)

# %%
txt = ['a','b','d','e']
txt.insert(2,'c')
print(txt)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
list1 = ["a", "b", ["c", ["d", "e", ["f", "g"], "k"], "l"], "m", "n"]
        # 0    1    200   210  211                    220   
# sub list to add
# understand indexing
# list1[2] = ['c', ['d', 'e', ['f', 'g'], 'k'], 'l']
# list1[2][1] = ['d', 'e', ['f', 'g'], 'k']
# list1[2][1][2] = ['f', 'g']
sub_list = ["h", "i", "j"]
print(list1[2][1][2][1])
# list1[2][1][2].extend(sub_list)
# print(list1)
# Out:
# g
